# %%
import re
import os
import pdfplumber
from bs4 import BeautifulSoup
import csv

# %%
def extract_html_text(html_path, selectors=None):
    soup = BeautifulSoup(html_path, "html.parser")
    
    # If no selectors provided, fallback to whole body text
    selectors = selectors or []
    
    texts = []
    for sel in selectors:
        panels = soup.find_all(class_=sel)
        for panel in panels:
            panel_text = panel.get_text(separator="\n", strip=True)
            texts.append(panel_text)
    
    # If nothing found from selectors, fallback to entire page text
    if not texts:
        texts = [soup.get_text(separator="\n", strip=True)]
    
    full_text = "\n\n".join(texts)
    
    # Clean extra whitespace
    cleaned_text = re.sub(r'\n\s*\n+', '\n\n', full_text)  # multiple blank lines → 2 newlines
    cleaned_text = re.sub(r'[ \t]+', ' ', cleaned_text)    # multiple spaces → 1 space
    
    return cleaned_text

# %%
def extract_pdf_text_and_tables(pdf_path):

    all_text = []

    with pdfplumber.open(pdf_path) as pdf:
        for i, page in enumerate(pdf.pages):
            # Extract text from the page
            text = page.extract_text() or ""
            all_text.append(f"\n\n{text}")

    return all_text

# %%
# Common selectors to try for extracting main content
selectors = [
    "accordion__panel",
    "main-content",
    "article-body",
    "content",
    "post-content",
    "entry-content",
    "page-content",
    "body-content",
    "text-content",
    "article",
    "post",
    # New: any class that starts with 'grid column'
    re.compile(r"^grid column"),
    "main", "div.content"
]

# %%
# Paths
raw_folders = ["../cmu_oie_scrape/html", "../cmu_oie_scrape/pdfs"]
output_folder = "../cmu_oie_scrape/cleaned"

os.makedirs(output_folder, exist_ok=True)

# %%
error_list = []

# Loop through both HTML and PDF folders
for raw_folder in raw_folders:
    for filename in os.listdir(raw_folder):
        file_path = os.path.join(raw_folder, filename)
        name, ext = os.path.splitext(filename)
        ext = ext.lower()

        try:
            prefix = "html_" if ext == ".html" else "pdf_" if ext == ".pdf" else None
            if prefix is None:
                continue

            output_path = os.path.join(output_folder, f"{prefix}{name.replace(' ', '_').lower()}.txt")

            if ext == ".html":
                with open(file_path, "r", encoding="utf-8") as f:
                    html = f.read()

                cleaned_text = extract_html_text(html, selectors)
                with open(output_path, "w", encoding="utf-8") as out_file:
                    out_file.write(cleaned_text)

                print(f"Saved cleaned HTML: {output_path}")

            elif ext == ".pdf":
                cleaned_text = extract_pdf_text_and_tables(file_path)
                with open(output_path, "w", encoding="utf-8") as out_file:
                    out_file.write("".join(cleaned_text))

                print(f"Saved cleaned PDF: {output_path}")

        except Exception as e:
            print(f"Error processing {file_path}: {e}")
            error_list.append({"file": file_path, "error": str(e)})

# Save error list to CSV
if error_list:
    error_csv_path = os.path.join(output_folder, "error_log.csv")
    with open(error_csv_path, "w", newline="", encoding="utf-8") as csvfile:
        fieldnames = ["file", "error"]
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()
        writer.writerows(error_list)

    print(f"\nErrors logged in: {error_csv_path}")
else:
    print("\nAll files processed successfully — no errors.")
# Out:
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_curricular-practical-training.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_on-campus-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_h1b-cap-gap-extension.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_i765-instructions.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_on-campus-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_h1b-cap-gap-extension.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_i765-instructions.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_opt-stem-extension.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_post-completion-opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_pre-completion-opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_severe-economic-hardship.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_opt-stem-extension.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_post-completion-opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_opt-stem-opt-extension_pre-completion-opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_f1-students_severe-economic-hardship.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_academic-training-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_on-campus-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_academic-training-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_j1-students_on-campus-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_opt-reporting.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_apply-for-ssn.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_f1-to-h1b-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_opt-reporting.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_apply-for-ssn.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_f1-to-h1b-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_replacement-ead-card.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_replacement-ead-card.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_us-permanent-residency.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_work-authorization.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_h1b-workers.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_us-permanent-residency.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_resources_work-authorization.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_h1b-workers.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_j1-scholar-employment-issues.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_j1-scholars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_b-visitors-visa-waiver.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_b-vs-j-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_e3-australians.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_j1-scholar-employment-issues.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_j1-scholars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_b-visitors-visa-waiver.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_b-vs-j-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_e3-australians.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_j2-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_o1-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_tn-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_j2-employment.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_o1-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_scholars_other-work-categories_tn-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_stem-opt-reporting.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_volunteering.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_health-insurance.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_home-residency.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_stem-opt-reporting.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_employment_volunteering.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_health-insurance.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_home-residency.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_i539.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_legal-resources.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_public-charge.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_i539.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_legal-resources.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_public-charge.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2020-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2021-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2022-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2020-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2021-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2022-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2023-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_archive_2023-tax-information.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_extending-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_h1b-maintaining-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_resources_tax-information_students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_extending-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_h1b-maintaining-status.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_leaving-cmu.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_time-limits-bars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_course-load-modality.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_documents.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_extending-i20-ds2019.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_leaving-cmu.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_scholars_time-limits-bars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_course-load-modality.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_documents.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_extending-i20-ds2019.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_leaving-carnegie-mellon.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_loa-suspension-dismissal.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_program-degree-change.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_leaving-carnegie-mellon.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_loa-suspension-dismissal.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_maintaining-status_students_program-degree-change.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_f1-and-j1-students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_f1-and-j1-students_opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_h1b-workers.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_f1-and-j1-students_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_f1-and-j1-students_opt.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_h1b-workers.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_j1-scholars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_domestic_drivers-license.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_domestic_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_families-dependents_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_documents_j1-scholars.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_domestic_drivers-license.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_domestic_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_families-dependents_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_families-dependents_infant-passport.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_government-agencies_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_automatic-visa-revalidation.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_families-dependents_infant-passport.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_government-agencies_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_automatic-visa-revalidation.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_index.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_renew.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_schengen.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_third-country.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_visa-delay-security-clearance.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_renew.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_schengen.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_third-country.txt
# Saved cleaned HTML: ../cmu_oie_scrape/cleaned\html_oie_travel_visa_visa-delay-security-clearance.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_collaborating-visitor_documents_collaborating-visitor-questinnaire.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_collaborating-visitor_documents_collaborating-visitor-questinnaire.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_hub_docs_return-loa.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_hub_docs_return-loa.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_hub_docs_withdrawal.txt
# Error processing ../cmu_oie_scrape/pdfs\my-workday-toolkit_quick-guides_restricted_quick-guide-w2.pdf: No /Root object! - Is this really a PDF?
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_hub_docs_withdrawal.txt
# Error processing ../cmu_oie_scrape/pdfs\my-workday-toolkit_quick-guides_restricted_quick-guide-w2.pdf: No /Root object! - Is this really a PDF?
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_immapp.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_immapp.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_insurance.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_insurance.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_permres.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_permres.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_sample2.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_sample2.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_tn-handout.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_academic-training-employer-attestation.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_administrators_docs_tn-handout.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_academic-training-employer-attestation.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_academic-training-j-1.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_change-of-college.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_academic-training-j-1.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_change-of-college.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_change-program.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_change-program.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_cpt-advisor-recommendation.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_cpt-advisor-recommendation.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_dependent-request-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_dependent-request-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_i983-instructions-handout.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_i983-instructions-handout.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_immapp.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_immapp.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_j-on-camp-fillable.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_j-on-camp-fillable.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_post-opt-advisor-recommendation.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_post-opt-advisor-recommendation.txt
# Cannot set gray non-stroke color because /'Paint10' is an invalid float value
# Cannot set gray non-stroke color because /'Paint14' is an invalid float value
# Cannot set gray non-stroke color because /'Paint14' is an invalid float value
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_power-points_employment-authorization-overview.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_power-points_opt-pre.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_power-points_opt-pre.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_power-points_stem-opt-slides.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_power-points_stem-opt-slides.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_pre-opt-academic-advisor-recommendation-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_pre-opt-academic-advisor-recommendation-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_program-extension.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_program-extension.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_reduced.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_reduced.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_request-services.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_request-services.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_sample-i765-pre-post.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_sample-i765-pre-post.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_scholar-data.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_scholar-data.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_sevis-fee.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_sevis-fee.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssdirect.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssdirect.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssn-form-externalvendor.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssn-form-externalvendor.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssn-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_ssn-form.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_updatedsample_employer_offer_letter_cpt.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_docs_updatedsample_employer_offer_letter_cpt.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_grad-affidavit-of-support.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_grad-affidavit-of-support.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_reduced.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_reduced.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_sample-job-duties-descriptions.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_sample-job-duties-descriptions.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_undergrad-affidavit-updated.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_foreign-students_docs_undergrad-affidavit-updated.txt
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_travel_visa_us-visa-in-canada.txt
#
# Errors logged in: ../cmu_oie_scrape/cleaned\error_log.csv
# Saved cleaned PDF: ../cmu_oie_scrape/cleaned\pdf_oie_travel_visa_us-visa-in-canada.txt
#
# Errors logged in: ../cmu_oie_scrape/cleaned\error_log.csv
